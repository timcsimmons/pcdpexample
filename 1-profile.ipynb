# %% [markdown]
# # PCDP 2014 Data Profile

# %%
import numpy as np
import pandas as pd
pd.options.display.max_rows = 10000

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

import sqlite3
import pcdp

def table(column, data=None):
    t = data.groupby(column)[[column]].count()
    t.index = t.index.astype('object')
    
    t['n'] = t[column].dropna()
    t['%'] = np.round(t['n']/t['n'].sum()*1000)/10
    
    return t[['n', '%']]

# %%
visit = pcdp.load_data('visit')

# %%
visit.head()
# Out:
#    Year   Visit  Patient  Gender                       Race     Ethnicity  \
# 0  2014  787284        2    Male                      Other      Hispanic
# 1  2014  235413        8  Female                      White  Non-Hispanic
# 2  2014  453897       10  Female  Black or African American  Non-Hispanic
# 3  2014  781662       10  Female  Black or African American  Non-Hispanic
# 4  2014  175773       37    Male                      White      Hispanic
#
#     TriageCat                   PayerType EDDisposition    ModeOfArrival  \
# 0   Non-acute  Medicaid (including SCHIP)    Discharged  Non-EMS/Walk-in
# 1    Emergent  Medicaid (including SCHIP)      Admitted  Non-EMS/Walk-in
# 2      Urgent  Medicaid (including SCHIP)      Admitted  Non-EMS/Walk-in
# 3    Emergent  Medicaid (including SCHIP)      Admitted  Non-EMS/Walk-in
# 4  Not-urgent  Medicaid (including SCHIP)    Discharged  Non-EMS/Walk-in
#
#    AgeInYears  AgeInMonths  AgeInDays TriageDayofWeek  TriageHour  \
# 0           5           69       2128          Monday        11.0
# 1          14          176       5378        Saturday        22.0
# 2           6           72       2210          Monday        19.0
# 3           6           76       2335          Sunday        17.0
# 4           6           75       2311         Tuesday        18.0
#
#    TriageToDischargeMinutes
# 0                     188.0
# 1                     198.0
# 2                     385.0
# 3                     332.0
# 4                     143.0

# %% [markdown]
# We need to verify that the files have been read correctly

# %%
categoricals = ['Year',
                'Gender', 'Race', 'Ethnicity',
                'TriageCat', 'PayerType', 'EDDisposition', 'ModeOfArrival',
                'AgeInYears',
                'TriageDayofWeek', 'TriageHour']

visit_frequencies = pd.concat([table(c, data=visit) for c in categoricals], keys=categoricals)
visit_frequencies
# Out:
#                                                                           n  \
# Year            2014                                                1184378
# Gender          Female                                               558655
#                 Male                                                 625676
#                 Stated Unknown                                           47
# Race            American Indian or Alaskan Native                      1899
#                 Asian                                                 20944
#                 Black or African American                            442214
#                 Native Hawaiian or Other Pacific Islander              3077
#                 White                                                484619
#                 Multiple Races                                        32685
#                 Stated Unknown                                        45976
#                 Other                                                145871
# Ethnicity       Hispanic                                             258180
#                 Non-Hispanic                                         889486
#                 Stated Unknown                                        26771
# TriageCat       Critical                                               8149
#                 Emergent                                             176498
#                 Urgent                                               407572
#                 Not-urgent                                           437205
#                 Non-acute                                            123697
#                 Unknown                                                5725
# PayerType       Commercial Insurance                                 368599
#                 Medicaid (including SCHIP)                           745627
#                 Medicare                                               2651
#                 Other                                                  2050
#                 Other Governmental Insurance (including CHAMPUS...    11717
#                 Self Pay                                              44065
#                 Workers Compensation                                     33
# EDDisposition   23 Hour Observation Unit/RTU                          15184
#                 Admitted                                             160550
#                 Left Against Medical Advice                            1777
#                 Died                                                    341
#                 Discharged                                           967376
#                 Left Without Treatment                                17270
#                 Other                                                  3149
#                 Stated Unknown                                            1
#                 Transferred                                            7014
# ModeOfArrival   EMS Air                                                2224
#                 EMS Ground                                           100600
#                 Non-EMS/Walk-in                                     1003371
#                 Other                                                 12611
#                 Stated Unknown                                         5816
# AgeInYears      0                                                    188045
#                 1                                                    152135
#                 2                                                    106081
#                 3                                                     83844
#                 4                                                     70469
#                 5                                                     65780
#                 6                                                     58347
#                 7                                                     50585
#                 8                                                     44659
#                 9                                                     42004
#                 10                                                    39994
#                 11                                                    37590
#                 12                                                    37108
#                 13                                                    37959
#                 14                                                    39457
#                 15                                                    40346
#                 16                                                    39370
#                 17                                                    34859
#                 18                                                    15746
# TriageDayofWeek Sunday                                               173363
#                 Monday                                               185446
#                 Tuesday                                              171897
#                 Wednesday                                            169450
#                 Thursday                                             163739
#                 Friday                                               159917
#                 Saturday                                             160566
# TriageHour      0                                                     37494
#                 1                                                     25701
#                 2                                                     19386
#                 3                                                     15767
#                 4                                                     13417
#                 5                                                     11980
#                 6                                                     12838
#                 7                                                     17837
#                 8                                                     31978
#                 9                                                     47825
#                 10                                                    57852
#                 11                                                    65140
#                 12                                                    65125
#                 13                                                    64798
#                 14                                                    62562
#                 15                                                    64201
#                 16                                                    68238
#                 17                                                    73083
#                 18                                                    77908
#                 19.0                                                  81649
#                 20.0                                                  79475
#                 21.0                                                  73761
#                 22.0                                                  62662
#                 23.0                                                  47926
#
#                                                                         %
# Year            2014                                                100.0
# Gender          Female                                               47.2
#                 Male                                                 52.8
#                 Stated Unknown                                        0.0
# Race            American Indian or Alaskan Native                     0.2
#                 Asian                                                 1.8
#                 Black or African American                            37.6
#                 Native Hawaiian or Other Pacific Islander             0.3
#                 White                                                41.2
#                 Multiple Races                                        2.8
#                 Stated Unknown                                        3.9
#                 Other                                                12.4
# Ethnicity       Hispanic                                             22.0
#                 Non-Hispanic                                         75.7
#                 Stated Unknown                                        2.3
# TriageCat       Critical                                              0.7
#                 Emergent                                             15.2
#                 Urgent                                               35.2
#                 Not-urgent                                           37.7
#                 Non-acute                                            10.7
#                 Unknown                                               0.5
# PayerType       Commercial Insurance                                 31.4
#                 Medicaid (including SCHIP)                           63.5
#                 Medicare                                              0.2
#                 Other                                                 0.2
#                 Other Governmental Insurance (including CHAMPUS...    1.0
#                 Self Pay                                              3.8
#                 Workers Compensation                                  0.0
# EDDisposition   23 Hour Observation Unit/RTU                          1.3
#                 Admitted                                             13.7
#                 Left Against Medical Advice                           0.2
#                 Died                                                  0.0
#                 Discharged                                           82.5
#                 Left Without Treatment                                1.5
#                 Other                                                 0.3
#                 Stated Unknown                                        0.0
#                 Transferred                                           0.6
# ModeOfArrival   EMS Air                                               0.2
#                 EMS Ground                                            8.9
#                 Non-EMS/Walk-in                                      89.2
#                 Other                                                 1.1
#                 Stated Unknown                                        0.5
# AgeInYears      0                                                    15.9
#                 1                                                    12.8
#                 2                                                     9.0
#                 3                                                     7.1
#                 4                                                     5.9
#                 5                                                     5.6
#                 6                                                     4.9
#                 7                                                     4.3
#                 8                                                     3.8
#                 9                                                     3.5
#                 10                                                    3.4
#                 11                                                    3.2
#                 12                                                    3.1
#                 13                                                    3.2
#                 14                                                    3.3
#                 15                                                    3.4
#                 16                                                    3.3
#                 17                                                    2.9
#                 18                                                    1.3
# TriageDayofWeek Sunday                                               14.6
#                 Monday                                               15.7
#                 Tuesday                                              14.5
#                 Wednesday                                            14.3
#                 Thursday                                             13.8
#                 Friday                                               13.5
#                 Saturday                                             13.6
# TriageHour      0                                                     3.2
#                 1                                                     2.2
#                 2                                                     1.6
#                 3                                                     1.3
#                 4                                                     1.1
#                 5                                                     1.0
#                 6                                                     1.1
#                 7                                                     1.5
#                 8                                                     2.7
#                 9                                                     4.1
#                 10                                                    4.9
#                 11                                                    5.5
#                 12                                                    5.5
#                 13                                                    5.5
#                 14                                                    5.3
#                 15                                                    5.4
#                 16                                                    5.8
#                 17                                                    6.2
#                 18                                                    6.6
#                 19.0                                                  6.9
#                 20.0                                                  6.7
#                 21.0                                                  6.3
#                 22.0                                                  5.3
#                 23.0                                                  4.1

# %%
continuous = ['AgeInMonths', 'AgeInDays', 'TriageToDischargeMinutes']
pd.concat([visit[s].dropna().describe() for s in continuous], keys=continuous).unstack()
# Out:
#                               count         mean            std         min  \
# AgeInMonths               1184378.0    77.093659      65.392156         0.0
# AgeInDays                 1184378.0  2361.111756    1990.429379         0.0
# TriageToDischargeMinutes  1178594.0   387.894704  193735.909057 -60093007.0
#
#                             25%     50%     75%         max
# AgeInMonths                20.0    58.0   127.0       227.0
# AgeInDays                 609.0  1780.0  3889.0      6939.0
# TriageToDischargeMinutes  101.0   163.0   254.0  45667256.0

# %% [markdown]
# Numerical summaries like these will only get you so far. We should create bar charts and histograms to see what's going on.

# %%
for grp, df in visit_frequencies.groupby(level=0):
    df.set_index(df.index.droplevel(), inplace=True)
    df[['%']].plot(kind='bar', title=grp)

# %% [markdown]
# Mostly these look good, but they aren't the most convenient variables in the world. We should make the following changes
#
# TODO
#
#   - Gender, Race, Ethnicity, TriageCat, PayerType, EDDisposition, ModeOfArrival have 'Unknown'
#   -  Race and ethnicity should be combined (White NH, Black NH, Other NH, Hispanic)
#   - PayerType should be simplified (commercial vs. government vs self-pay/other)
#   - EDisposition should be simplified (Hospitalized or worse vs. discharged or left)
#   - ModeOfArrival should be simplified (EMS vs. Non-EMS)

# %%
for c in continuous:
    visit[[c]].hist()

# %% [markdown]
# Clearly something is horribly wrong with TriageToDischargeMinutes. We should get rid of the negative values and truncate the times to fall within a 24 hour window (don't really care if the visit is longer).
#
# Fortunately, there is already a clean version of the visit table in the database.

# %%
visit = pcdp.load_data('pcdp')

# %%
visit.head()
# Out:
#    Year   Visit  Patient  Gender                       Race     Ethnicity  \
# 0  2014  787284        2    Male                      Other      Hispanic
# 1  2014  235413        8  Female                      White  Non-Hispanic
# 2  2014  453897       10  Female  Black or African American  Non-Hispanic
# 3  2014  781662       10  Female  Black or African American  Non-Hispanic
# 4  2014  175773       37    Male                      White      Hispanic
#
#   RaceEthnicity   TriageCat                   PayerType       Payer  \
# 0      Hispanic   Non-acute  Medicaid (including SCHIP)  Government
# 1      White NH    Emergent  Medicaid (including SCHIP)  Government
# 2      Black NH      Urgent  Medicaid (including SCHIP)  Government
# 3      Black NH    Emergent  Medicaid (including SCHIP)  Government
# 4      Hispanic  Not-urgent  Medicaid (including SCHIP)  Government
#
#   EDDisposition               SentHome    ModeOfArrival              EMS  \
# 0    Discharged      Sent home from ED  Non-EMS/Walk-in  Did not use EMS
# 1      Admitted  Not sent home from ED  Non-EMS/Walk-in  Did not use EMS
# 2      Admitted  Not sent home from ED  Non-EMS/Walk-in  Did not use EMS
# 3      Admitted  Not sent home from ED  Non-EMS/Walk-in  Did not use EMS
# 4    Discharged      Sent home from ED  Non-EMS/Walk-in  Did not use EMS
#
#    AgeInYears TriageDayofWeek  TriageHour    LOS
# 0    5.826466          Monday        11.0  188.0
# 1   14.724968        Saturday        22.0  198.0
# 2    6.050982          Monday        19.0  385.0
# 3    6.393232          Sunday        17.0  332.0
# 4    6.327520         Tuesday        18.0  143.0

# %%
categoricals = ['Year', 'Gender', 'Race', 'Ethnicity', 'RaceEthnicity', 'TriageCat', 'PayerType', 'Payer',
                'EDDisposition', 'SentHome', 'ModeOfArrival', 'EMS', 'TriageDayofWeek', 'TriageHour']
continuous = ['AgeInYears', 'LOS']

# %%
visit_frequencies = pd.concat([table(c, data=visit) for c in categoricals], keys=categoricals)
visit_frequencies
# Out:
#                                                                           n  \
# Year            2014                                                1184378
# Gender          Female                                               558655
#                 Male                                                 625676
# Race            American Indian or Alaskan Native                      1899
#                 Asian                                                 20944
#                 Black or African American                            442214
#                 Native Hawaiian or Other Pacific Islander              3077
#                 White                                                484619
#                 Multiple Races                                        32685
#                 Other                                                145871
# Ethnicity       Hispanic                                             258180
#                 Non-Hispanic                                         889486
# RaceEthnicity   White NH                                             381107
#                 Black NH                                             430400
#                 Hispanic                                             258180
#                 Other NH                                              92515
# TriageCat       Critical                                               8149
#                 Emergent                                             176498
#                 Urgent                                               407572
#                 Not-urgent                                           437205
#                 Non-acute                                            123697
# PayerType       Commercial Insurance                                 368599
#                 Medicaid (including SCHIP)                           745627
#                 Medicare                                               2651
#                 Other                                                  2050
#                 Other Governmental Insurance (including CHAMPUS...    11717
#                 Self Pay                                              44065
#                 Workers Compensation                                     33
# Payer           Commercial insurance                                 368599
#                 Government                                           759995
#                 Self-pay/Other                                        46148
# EDDisposition   23 Hour Observation Unit/RTU                          15184
#                 Admitted                                             160550
#                 Left Against Medical Advice                            1777
#                 Died                                                    341
#                 Discharged                                           967376
#                 Left Without Treatment                                17270
#                 Other                                                  3149
#                 Transferred                                            7014
# SentHome        Not sent home from ED                                171054
#                 Sent home from ED                                   1001607
# ModeOfArrival   EMS Air                                                2224
#                 EMS Ground                                           100600
#                 Non-EMS/Walk-in                                     1003371
#                 Other                                                 12611
# EMS             Did not use EMS                                     1015982
#                 Used EMS                                             102824
# TriageDayofWeek Sunday                                               173363
#                 Monday                                               185446
#                 Tuesday                                              171897
#                 Wednesday                                            169450
#                 Thursday                                             163739
#                 Friday                                               159917
#                 Saturday                                             160566
# TriageHour      0.0                                                   37494
#                 1.0                                                   25701
#                 2.0                                                   19386
#                 3.0                                                   15767
#                 4.0                                                   13417
#                 5.0                                                   11980
#                 6.0                                                   12838
#                 7.0                                                   17837
#                 8.0                                                   31978
#                 9.0                                                   47825
#                 10.0                                                  57852
#                 11.0                                                  65140
#                 12.0                                                  65125
#                 13.0                                                  64798
#                 14.0                                                  62562
#                 15.0                                                  64201
#                 16.0                                                  68238
#                 17.0                                                  73083
#                 18.0                                                  77908
#                 19.0                                                  81649
#                 20.0                                                  79475
#                 21.0                                                  73761
#                 22.0                                                  62662
#                 23.0                                                  47926
#
#                                                                         %
# Year            2014                                                100.0
# Gender          Female                                               47.2
#                 Male                                                 52.8
# Race            American Indian or Alaskan Native                     0.2
#                 Asian                                                 1.9
#                 Black or African American                            39.1
#                 Native Hawaiian or Other Pacific Islander             0.3
#                 White                                                42.8
#                 Multiple Races                                        2.9
#                 Other                                                12.9
# Ethnicity       Hispanic                                             22.5
#                 Non-Hispanic                                         77.5
# RaceEthnicity   White NH                                             32.8
#                 Black NH                                             37.0
#                 Hispanic                                             22.2
#                 Other NH                                              8.0
# TriageCat       Critical                                              0.7
#                 Emergent                                             15.3
#                 Urgent                                               35.3
#                 Not-urgent                                           37.9
#                 Non-acute                                            10.7
# PayerType       Commercial Insurance                                 31.4
#                 Medicaid (including SCHIP)                           63.5
#                 Medicare                                              0.2
#                 Other                                                 0.2
#                 Other Governmental Insurance (including CHAMPUS...    1.0
#                 Self Pay                                              3.8
#                 Workers Compensation                                  0.0
# Payer           Commercial insurance                                 31.4
#                 Government                                           64.7
#                 Self-pay/Other                                        3.9
# EDDisposition   23 Hour Observation Unit/RTU                          1.3
#                 Admitted                                             13.7
#                 Left Against Medical Advice                           0.2
#                 Died                                                  0.0
#                 Discharged                                           82.5
#                 Left Without Treatment                                1.5
#                 Other                                                 0.3
#                 Transferred                                           0.6
# SentHome        Not sent home from ED                                14.6
#                 Sent home from ED                                    85.4
# ModeOfArrival   EMS Air                                               0.2
#                 EMS Ground                                            9.0
#                 Non-EMS/Walk-in                                      89.7
#                 Other                                                 1.1
# EMS             Did not use EMS                                      90.8
#                 Used EMS                                              9.2
# TriageDayofWeek Sunday                                               14.6
#                 Monday                                               15.7
#                 Tuesday                                              14.5
#                 Wednesday                                            14.3
#                 Thursday                                             13.8
#                 Friday                                               13.5
#                 Saturday                                             13.6
# TriageHour      0.0                                                   3.2
#                 1.0                                                   2.2
#                 2.0                                                   1.6
#                 3.0                                                   1.3
#                 4.0                                                   1.1
#                 5.0                                                   1.0
#                 6.0                                                   1.1
#                 7.0                                                   1.5
#                 8.0                                                   2.7
#                 9.0                                                   4.1
#                 10.0                                                  4.9
#                 11.0                                                  5.5
#                 12.0                                                  5.5
#                 13.0                                                  5.5
#                 14.0                                                  5.3
#                 15.0                                                  5.4
#                 16.0                                                  5.8
#                 17.0                                                  6.2
#                 18.0                                                  6.6
#                 19.0                                                  6.9
#                 20.0                                                  6.7
#                 21.0                                                  6.3
#                 22.0                                                  5.3
#                 23.0                                                  4.1

# %%
pd.concat([visit[s].dropna().describe() for s in continuous], keys=continuous).unstack()
# Out:
#                 count        mean         std  min         25%         50%  \
# AgeInYears  1184378.0    6.464726    5.449797  0.0    1.667442    4.873641
# LOS         1178436.0  210.734133  198.787174  0.0  101.000000  163.000000
#
#                    75%          max
# AgeInYears   10.648085    18.998987
# LOS         254.000000  1440.000000

# %%
24*60
# Out:
# 1440

# %%
for grp, df in visit_frequencies.groupby(level=0):
    df.set_index(df.index.droplevel(), inplace=True)
    df[['%']].plot(kind='bar', title=grp)

# %%
for c in continuous:
    visit[[c]].hist()
